# %%
print("Hello Jupyter!")
# Out:
# Hello Jupyter!

# %%
x = 10
y = 20

print(x + y)
# Out:
# 30

# %%
import pandas as pd

df = pd.DataFrame({
    "Name": ["Alice", "Bob", "Carol"],
    "Age": [25, 30, 28]
})

df
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30
# 2  Carol   28

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4], [2,4,6,8])
plt.title("First Graph")
plt.show()
